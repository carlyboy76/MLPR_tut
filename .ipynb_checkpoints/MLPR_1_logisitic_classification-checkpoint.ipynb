# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#%matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# create some data
# 2 classes from different Gaussian distributions: class A labelled "0", class B labelled "1"
# (data constructed so that the decision boundary given makes sense)

n = 200

mean_pos = (1,2)
mean_neg = (-3,-6)
var = 4

x_pos = np.random.normal(loc=mean_pos, scale=var, size=(n/2,2))
x_pos = np.append(x_pos,np.ones((n/2,1)),axis=1)

x_neg = np.random.normal(loc=mean_neg, scale=var, size=(n/2,2))
x_neg = np.append(x_neg,np.zeros((n/2,1)),axis=1)

x = np.append(x_pos, x_neg, axis=0)

# %%
# illustrating the data:

#positive cases
print x[:5,:]

#negative cases
print x[-5:,:]
# Out:
# [[-0.43815873 -3.14858764  1.        ]
#  [ 5.89576586 -7.37960859  1.        ]
#  [ 0.81200063 -2.48218243  1.        ]
#  [ 1.89299718  2.57546511  1.        ]
#  [ 1.71460259  5.28304626  1.        ]]
# [[-3.9154203  -1.23117821  0.        ]
#  [-2.98713199 -1.74867802  0.        ]
#  [-3.72507835 -9.78084954  0.        ]
#  [-8.8195895  -4.21055823  0.        ]
#  [ 0.56505684 -8.76714953  0.        ]]

# %%
# plot the data, show v and decision boundary for v' = [1,2], b = 5

fig, ax = plt.subplots()

gs = 10
ax.set_xlim(-gs, gs)
ax.set_ylim(-gs, gs)

plt.scatter(x_pos[:,0], x_pos[:,1], c="r")
plt.scatter(x_neg[:,0], x_neg[:,1], c="b")

# sort out axes
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot v
v = [0,2]
plt.plot(v,c="green")

# plot boundary
b_x_1 = np.arange(-gs, gs, 0.1)
b_x_2 = -b_x_1/2 - 2.5
plt.plot(b_x_1, b_x_2, c="purple")

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# plot data in the (x1,x2)-plane

fig = plt.figure()
ax = plt.axes(projection='3d')

z = x[:,2]
x1 = x[:,0]
x2 = x[:,1]

ax.scatter(x1, x2, 0, c=z)

# %%
# logistic regression assigns a value f(x) = sigmoid(v'x + b) to each point x in the (x1, x2)-plane
#  - consider inner term g(x) = v'x + b, is a plane P
#  - decision boundary is where f(x)=0.5 => g(x)=0  =>  plane P cuts through the (x1, x2)-plane

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(x1, x2, 0, c=z)

x1_range = np.outer(np.linspace(-8, 8, 10), np.ones(10))
x2_range = x1_range.copy().T
plane = x1_range * 2 + x2_range * 2 + 5
sigmoid = 1 / (1 + np.exp(-plane))

#ax.set_zlim(-1.5, 1.5)

ax.plot_wireframe(x1_range, x2_range, plane)

# %%
# we want f(x) to fit the probability of x belonging to class B, (where true probs are given by the data labels)

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(x1, x2, z, c=z)

# %%
# apply sigmoid to planar values (v'x + b)
# i.e. f(x) = sigmoid(v'x + b) and compare to true label values, y, (which are now comparable)
# so fit parameters (i.e. w & b) to get lowest loss (i.e. difference between f(x) and ys)

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(x1, x2, z, c=z)
ax.set_zlim(-.1, 1.1)

ax.plot_wireframe(x1_range, x2_range, sigmoid)

# %%
# As the function f(x) assigns values over the space of the data, can consider contours of f(x) within the 
# subspace of the data, i.e. lines in which f(x) is constant.
